# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedyahia01/ComfyUI-Colab/blob/main/animatediff_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 1. تحديد إعداد بيئة Colab لاستخدام GPU
# من القائمة: Runtime → Change runtime type → اختر GPU

### 2. ربط Google Drive
from google.colab import drive
drive.mount('/content/drive')

### 3. إعداد مجلد ComfyUI داخل Drive
# !mkdir -p /content/drive/MyDrive/ComfyUI

### 4. تحميل/تحديث ComfyUI
# %cd /content/drive/MyDrive/ComfyUI
# !git clone https://github.com/comfyanonymous/ComfyUI.git . || (git pull)

### 5. تنصيب التبعيات
# !python -m pip install --upgrade pip
# !pip install -r requirements.txt

### 6. تشغيل ComfyUI في الخلفية
import time, os, re
# %cd /content/drive/MyDrive/ComfyUI
get_ipython().system_raw('python main.py --listen 0.0.0.0 --port 8188 > comfy.log 2>&1 &')
time.sleep(5)
# !tail -n 20 comfy.log

### 7. محاولة تشغيل Cloudflared
print("🔄 محاولة تشغيل Cloudflared...")
# !wget -q -O cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared
get_ipython().system_raw('./cloudflared tunnel --url http://localhost:8188 --no-autoupdate > cloudflared.log 2>&1 &')
time.sleep(6)

# استخراج الرابط
link = None
with open("/content/drive/MyDrive/ComfyUI/cloudflared.log", "r") as f:
    content = f.read()
    match = re.search(r"https://[A-Za-z0-9_-]+\.trycloudflare\.com", content)
    if match:
        link = match.group(0)

### 8. إذا فشل Cloudflared، استخدام ngrok
if link:
    print("✅ رابط ComfyUI عبر Cloudflared:", link)
else:
    print("⚠️ فشل Cloudflared، محاولة استخدام ngrok...")
    # !pip install pyngrok
    from pyngrok import ngrok
    public_url = ngrok.connect(8188)
    print("✅ رابط ComfyUI عبر ngrok:", public_url)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ComfyUI
# fatal: destination path '.' already exists and is not an empty directory.
# Already up to date.
# ...
# /content/drive/MyDrive/ComfyUI
# /usr/bin/python3: No module named uv
# Failed to execute startup-script: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/prestartup_script.py / Command '['/usr/bin/python3', '-m', 'uv', 'pip', 'freeze']' returned non-zero exit status 1.
#
# Prestartup times for custom nodes:
#    0.4 seconds (PRESTARTUP FAILED): /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# 🔄 محاولة تشغيل Cloudflared...
# cloudflared: Text file busy
# ...
